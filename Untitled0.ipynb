# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install string-grouper
# Out:
# Requirement already satisfied: string-grouper in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from string-grouper) (1.21.6)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.7/dist-packages (from string-grouper) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from string-grouper) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from string-grouper) (1.0.2)
# Requirement already satisfied: topn>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from string-grouper) (0.0.7)
# Requirement already satisfied: sparse-dot-topn-for-blocks>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from string-grouper) (0.3.1.post3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->string-grouper) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->string-grouper) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->string-grouper) (1.15.0)
# Requirement already satisfied: cython>=0.29.15 in /usr/local/lib/python3.7/dist-packages (from sparse-dot-topn-for-blocks>=0.3.1->string-grouper) (0.29.29)
# Requirement already satisfied: setuptools>=42 in /usr/local/lib/python3.7/dist-packages (from sparse-dot-topn-for-blocks>=0.3.1->string-grouper) (57.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->string-grouper) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->string-grouper) (3.1.0)

# %%
cd '/content/drive/MyDrive/Colab/THDL'
# Out:
# /content/drive/MyDrive/Colab/THDL

# %%
import pandas as pd
import numpy as np
from string_grouper import match_strings, match_most_similar, group_similar_strings, compute_pairwise_similarities, StringGrouper

# %% [markdown]
# **Find all matches within a single data set**

# %%
company_names = 'sec__edgar_company_info.csv'
# We only look at the first 50k as an example:
companies = pd.read_csv(company_names)[0:50000]
# Create all matches:
n_blocks = 'auto'
matches = match_strings(companies['Company Name'],n_blocks = 'auto' )
# Look at only the non-exact matches:
matches[matches['left_Company Name'] != matches['right_Company Name']].head()
# Out:
# /usr/local/lib/python3.7/dist-packages/string_grouper/string_grouper.py:492: UserWarning: An OverflowError occurred but is being handled.  The input data will be automatically split-up into smaller chunks which will then be processed one chunk at a time.  To prevent OverflowError, use the n_blocks parameter to split-up the data manually into small enough chunks.
#   warnings.warn("An OverflowError occurred but is being "
#      left_index                        left_Company Name  similarity  \
# 15         4211                                90210 LLC    0.870291
# 167         166            1 800 MUTUALS ADVISORS SERIES    0.931615
# 168         165             1 800 MUTUALS ADVISOR SERIES    0.931615
# 172         201            1-800-RADIATOR FRANCHISE INC.    1.000000
# 178         174  1 FINANCIAL MARKETPLACE SECURITIES, LLC    0.949364
#
#                                     right_Company Name  right_index
# 15                                           0210, LLC           14
# 167                       1 800 MUTUALS ADVISOR SERIES          165
# 168                      1 800 MUTUALS ADVISORS SERIES          166
# 172                       1 800 RADIATOR FRANCHISE INC          168
# 178  1 FINANCIAL MARKETPLACE SECURITIES LLC        ...          173

# %% [markdown]
# **Find all matches in between two data sets.**

# %%
# Create a small set of artificial company names:
duplicates = pd.Series(['S MEDIA GROUP', '012 SMILE.COMMUNICATIONS', 'foo bar', 'B4UTRADE COM CORP'])
# Create all matches:
matches = match_strings(companies['Company Name'], duplicates)
matches
# Out:
#    left_index             left_Company Name  similarity  \
# 0       49777            B.A.S. MEDIA GROUP    0.854383
# 1          12  012 SMILE.COMMUNICATIONS LTD    0.944092
# 2       49855             B4UTRADE COM CORP    1.000000
# 3       49857                 B4UTRADE CORP    0.878276
# 4       49856              B4UTRADE COM INC    0.810217
#
#                  right_side  right_index
# 0             S MEDIA GROUP            0
# 1  012 SMILE.COMMUNICATIONS            1
# 2         B4UTRADE COM CORP            3
# 3         B4UTRADE COM CORP            3
# 4         B4UTRADE COM CORP            3

# %% [markdown]
# **For a second data set, find only the most similar match**

# %%
# Create a small set of artificial company names:
new_companies = pd.Series(['S MEDIA GROUP', '012 SMILE.COMMUNICATIONS', 'foo bar', 'B4UTRADE COM CORP'],\
                          name='New Company')
# Create all matches:
matches = match_most_similar(companies['Company Name'], new_companies, ignore_index=True)
# Display the results:
pd.concat([new_companies, matches], axis=1)
# Out:
#                 New Company     most_similar_Company Name
# 0             S MEDIA GROUP            B.A.S. MEDIA GROUP
# 1  012 SMILE.COMMUNICATIONS  012 SMILE.COMMUNICATIONS LTD
# 2                   foo bar                       foo bar
# 3         B4UTRADE COM CORP             B4UTRADE COM CORP

# %% [markdown]
# **Deduplicate a single data set and show items with most duplicates**

# %%
# Add the grouped strings:
companies['deduplicated_name'] = group_similar_strings(companies['Company Name'],
                                                       ignore_index=True, n_blocks = 'auto')
# Show items with most duplicates:
companies.groupby('deduplicated_name')['Line Number'].count().sort_values(ascending=False).head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/string_grouper/string_grouper.py:492: UserWarning: An OverflowError occurred but is being handled.  The input data will be automatically split-up into smaller chunks which will then be processed one chunk at a time.  To prevent OverflowError, use the n_blocks parameter to split-up the data manually into small enough chunks.
#   warnings.warn("An OverflowError occurred but is being "
# deduplicated_name
# ADVISORS DISCIPLINED TRUST                                      1824
# AGL LIFE ASSURANCE CO SEPARATE ACCOUNT                           183
# ANGELLIST-ART-FUND, A SERIES OF ANGELLIST-FG-FUNDS, LLC          116
# AMERICREDIT AUTOMOBILE RECEIVABLES TRUST 2000-1                   87
# ACE SECURITIES CORP. HOME EQUITY LOAN TRUST, SERIES 2006-HE2      57
# ASSET-BACKED PASS-THROUGH CERTIFICATES SERIES 2004-W1             40
# ALLSTATE LIFE GLOBAL FUNDING TRUST 2005-3                         39
# ALLY AUTO RECEIVABLES TRUST 2014-1                                33
# ANDERSON ROBERT E /                                               28
# ADVENT INTERNATIONAL GPE VIII LIMITED PARTNERSHIP                 28
# Name: Line Number, dtype: int64

# %%
# Create a small set of artificial customer names:
customers_df = pd.DataFrame(
   [
      ('BB016741P', 'Mega Enterprises Corporation'),
      ('CC082744L', 'Hyper Startup Incorporated'),
      ('AA098762D', 'Hyper Startup Inc.'),
      ('BB099931J', 'Hyper-Startup Inc.'),
      ('HH072982K', 'Hyper Hyper Inc.')
   ],
   columns=('Customer ID', 'Customer Name')
).set_index('Customer ID')
# Display the data:
customers_df
# Out:
#                             Customer Name
# Customer ID
# BB016741P    Mega Enterprises Corporation
# CC082744L      Hyper Startup Incorporated
# AA098762D              Hyper Startup Inc.
# BB099931J              Hyper-Startup Inc.
# HH072982K                Hyper Hyper Inc.

# %%
# Group customers with similar names:
customers_df[["group-id", "name_deduped"]]  = \
    group_similar_strings(customers_df["Customer Name"])
# Display the mapping table:
customers_df
# Out:
#                             Customer Name   group-id  \
# Customer ID
# BB016741P    Mega Enterprises Corporation  BB016741P
# CC082744L      Hyper Startup Incorporated  CC082744L
# AA098762D              Hyper Startup Inc.  AA098762D
# BB099931J              Hyper-Startup Inc.  AA098762D
# HH072982K                Hyper Hyper Inc.  HH072982K
#
#                              name_deduped
# Customer ID
# BB016741P    Mega Enterprises Corporation
# CC082744L      Hyper Startup Incorporated
# AA098762D              Hyper Startup Inc.
# BB099931J              Hyper Startup Inc.
# HH072982K                Hyper Hyper Inc.

# %% [markdown]
# **Simply compute the cosine similarities of pairs of strings**

# %%
# Create a small DataFrame of pairs of strings:
pair_s = pd.DataFrame(
    [
        ('Mega Enterprises Corporation', 'Mega Enterprises Corporation'),
        ('Hyper Startup Inc.', 'Hyper Startup Incorporated'),
        ('Hyper Startup Inc.', 'Hyper Startup Inc.'),
        ('Hyper Startup Inc.', 'Hyper-Startup Inc.'),
        ('Hyper Hyper Inc.', 'Hyper Hyper Inc.'),
        ('Mega Enterprises Corporation', 'Mega Enterprises Corp.')
   ],
   columns=('left', 'right')
)
# Display the data:
pair_s
# Out:
#                            left                         right
# 0  Mega Enterprises Corporation  Mega Enterprises Corporation
# 1            Hyper Startup Inc.    Hyper Startup Incorporated
# 2            Hyper Startup Inc.            Hyper Startup Inc.
# 3            Hyper Startup Inc.            Hyper-Startup Inc.
# 4              Hyper Hyper Inc.              Hyper Hyper Inc.
# 5  Mega Enterprises Corporation        Mega Enterprises Corp.

# %%
# Compute their cosine similarities and display them:
pair_s['similarity'] = compute_pairwise_similarities(pair_s['left'], pair_s['right'])
pair_s
# Out:
#                            left                         right  similarity
# 0  Mega Enterprises Corporation  Mega Enterprises Corporation    1.000000
# 1            Hyper Startup Inc.    Hyper Startup Incorporated    0.633620
# 2            Hyper Startup Inc.            Hyper Startup Inc.    1.000000
# 3            Hyper Startup Inc.            Hyper-Startup Inc.    1.000000
# 4              Hyper Hyper Inc.              Hyper Hyper Inc.    1.000000
# 5  Mega Enterprises Corporation        Mega Enterprises Corp.    0.826463

# %% [markdown]
# **Class StringGrouper**

# %%
company_names = 'sec__edgar_company_info.csv'
companies = pd.read_csv(company_names)[0:50000]

# %%
# Create a new StringGrouper
string_grouper = StringGrouper(companies['Company Name'], ignore_index=True)
# Check if the ngram function does what we expect:
string_grouper.n_grams('McDonalds')
# Out:
# ['mcd', 'cdo', 'don', 'ona', 'nal', 'ald', 'lds']

# %%
# Now fit the StringGrouper - this will take a while since we are calculating cosine similarities on 600k strings
string_grouper = string_grouper.fit(n_blocks = 'auto')
# Out:
# /usr/local/lib/python3.7/dist-packages/string_grouper/string_grouper.py:492: UserWarning: An OverflowError occurred but is being handled.  The input data will be automatically split-up into smaller chunks which will then be processed one chunk at a time.  To prevent OverflowError, use the n_blocks parameter to split-up the data manually into small enough chunks.
#   warnings.warn("An OverflowError occurred but is being "

# %%
# Add the grouped strings
companies['deduplicated_name'] = string_grouper.get_groups()

# %%
companies[companies.deduplicated_name.str.contains('PRICEWATERHOUSECOOPERS LLP')]
# Out:
# Empty DataFrame
# Columns: [Line Number, Company Name, Company CIK Key, deduplicated_name]
# Index: []

# %%
companies[companies.deduplicated_name.str.contains('PWC')]
# Out:
# Empty DataFrame
# Columns: [Line Number, Company Name, Company CIK Key, deduplicated_name]
# Index: []

# %%
string_grouper = string_grouper.add_match('PRICEWATERHOUSECOOPERS LLP', 'PWC HOLDING CORP')
companies['deduplicated_name'] = string_grouper.get_groups()
# Now lets check again:

companies[companies.deduplicated_name.str.contains('PRICEWATERHOUSECOOPERS LLP')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3e3ee756cf19> in <module>()
# ----> 1 string_grouper = string_grouper.add_match('PRICEWATERHOUSECOOPERS LLP', 'PWC HOLDING CORP')
#       2 companies['deduplicated_name'] = string_grouper.get_groups()
#       3 # Now lets check again:
#       4
#       5 companies[companies.deduplicated_name.str.contains('PRICEWATERHOUSECOOPERS LLP')]
#
# /usr/local/lib/python3.7/dist-packages/string_grouper/string_grouper.py in wrapper(*args, **kwargs)
#     209     def wrapper(*args, **kwargs):
#     210         if args[0].is_build:
# --> 211             return f(*args, **kwargs)
#     212         else:
#     213             raise StringGrouperNotFitException(f'{f.__name__} was called before the "fit" function was called.'
#
# /usr/local/lib/python3.7/dist-packages/string_grouper/string_grouper.py in add_match(self, master_side, dupe_side)
#     829     def add_match(self, master_side: str, dupe_side: str) -> 'StringGrouper':
#     830         """Adds a match if it wasn't found by the fit function"""
# --> 831         master_indices, dupe_indices = self._get_indices_of(master_side, dupe_side)
#     832
#     833         # add prior matches to new match
#
# /usr/local/lib/python3.7/dist-packages/string_grouper/string_grouper.py in _get_indices_of(self, master_side, dupe_side)
#    1067         dupe_strings = self._master if self._duplicates is None else self._duplicates
#    1068         # Check if input is valid:
# -> 1069         self._validate_strings_exist(master_side, dupe_side, master_strings, dupe_strings)
#    1070         # Get the indices of the two strings
#    1071         master_indices = master_strings[master_strings == master_side].index.to_series().reset_index(drop=True)
#
# /usr/local/lib/python3.7/dist-packages/string_grouper/string_grouper.py in _validate_strings_exist(master_side, dupe_side, master_strings, dupe_strings)
#    1140     def _validate_strings_exist(master_side, dupe_side, master_strings, dupe_strings):
#    1141         if not master_strings.isin([master_side]).any():
# -> 1142             raise ValueError(f'{master_side} not found in StringGrouper string series')
#    1143         elif not dupe_strings.isin([dupe_side]).any():
#    1144             raise ValueError(f'{dupe_side} not found in StringGrouper dupe string series')
#
# ValueError: PRICEWATERHOUSECOOPERS LLP not found in StringGrouper string series
